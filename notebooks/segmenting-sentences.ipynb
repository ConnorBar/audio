# %%
validated_df = pd.read_csv('./large-corpus/validated.tsv', sep='\t')
# Out:
# /tmp/ipykernel_3060337/497813418.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   validated_df = pd.read_csv('./large-corpus/validated.tsv', sep='\t')

# %%
validated_df.head()
# Out:
#                                            client_id  \
# 0  0294d9751511843184ab839d1837ab7a41a98348766864...
# 1  02bf7ccb5f078eb0294cc22f6d725720e4079d0190fa81...
# 2  02ec74191c6ccc7dcf6ecaa217268263c477273b4de93f...
# 3  039d72bf7503fe0261157341a5ba4bd017b6b5f000338b...
# 4  03f39c4095d773278747e6ab5e591484fb8cb133c7945c...
#
#                               path  \
# 0  common_voice_zh-CN_33411896.mp3
# 1  common_voice_zh-CN_32269533.mp3
# 2  common_voice_zh-CN_22069600.mp3
# 3  common_voice_zh-CN_33446629.mp3
# 4  common_voice_zh-CN_33615736.mp3
#
#                                          sentence_id  \
# 0  fc88f495ef25b785e3fbc0c56d95a74761d3ae1da57855...
# 1  8c25ebbacc7b9fcfcca3c1d22acba9181ce38edf00502d...
# 2  73f88858e2402cca1896ec78186d8db1a7f5e66221fc7f...
# 3  6a904363f29a6351d8ebb35fa72c6c7ca1d6fa7964ca41...
# 4  6a7f9a3a395f067bbc63d6263ca7a3ab1b8a7cdb5f5063...
#
#                     sentence sentence_domain  up_votes  down_votes  age  \
# 0     黑身准裂腹鱼为辐鳍鱼纲鲤形目鲤科的其中一种。             NaN         2           0  NaN
# 1                          否             NaN         2           1  NaN
# 2               宋朝末年年间定居粉岭围。             NaN         2           0  NaN
# 3        油小路通是京都市主要的南北向道路之一。             NaN         2           0  NaN
# 4  富尔马诺夫出生在科斯特罗马省谢列达的一个农民家庭。             NaN         2           0  NaN
#
#   gender accents  variant locale    segment
# 0    NaN     NaN      NaN  zh-CN        NaN
# 1    NaN     NaN      NaN  zh-CN  Benchmark
# 2    NaN     NaN      NaN  zh-CN        NaN
# 3    NaN     NaN      NaN  zh-CN        NaN
# 4    NaN     NaN      NaN  zh-CN        NaN

# %%
def breakdown_pinyin_v_to_u(phrase):
  clean_phrase = re.sub(r'[^\w]', '', phrase)
  initial = lazy_pinyin(clean_phrase, style=Style.INITIALS, strict=True)
  final = lazy_pinyin(clean_phrase, style=Style.FINALS, strict=True)
  tone = [ word[-1] for word in lazy_pinyin(clean_phrase, style=Style.FINALS_TONE3, strict=False, v_to_u=True, neutral_tone_with_five=True, tone_sandhi=True)]
  
  initial = [init if init != '' else "EMPTY" for init in initial ]

  return list(zip(initial, final, tone))

# %%
myDF = validated_df.copy()
myDF['pinyin_breakdown'] = myDF['sentence'].progress_apply(breakdown_pinyin_v_to_u)
myDF['words'] = myDF['sentence'].apply(lambda row: [char for char in re.sub(r'[^\w]', '', row)])
# Out:
# Processing data: 100%|██████████| 187414/187414 [01:30<00:00, 2074.27it/s]

# %%
mask = myDF.apply(lambda row: len(row['words']) == len(row['pinyin_breakdown']), axis=1)

# %%
filtered_myDF = myDF[mask]

# %%
better = filtered_myDF.explode(['words', 'pinyin_breakdown'])

# %%
better[['initial', 'final', 'tone']] = pd.DataFrame(better['pinyin_breakdown'].tolist(), index=better.index)

# %%
s = validated_df['sentence'].progress_apply(lambda row: lazy_pinyin(row))
# Out:
# Processing data: 100%|██████████| 187414/187414 [00:15<00:00, 12048.97it/s]

# %%
s
# Out:
# 0         [hei, shen, zhun, lie, fu, yu, wei, fu, qi, yu...
# 1                                                     [fou]
# 2         [song, chao, mo, nian, nian, jian, ding, ju, f...
# 3         [you, xiao, lu, tong, shi, jing, du, shi, zhu,...
# 4         [fu, er, ma, nuo, fu, chu, sheng, zai, ke, si,...
#                                 ...
# 187409    [zhe, bei, gong, he, pai, he, she, hui, zhu, y...
# 187410    [han, mo, shi, mi, si, shi, lun, dun, de, yi, ...
# 187411    [bei, chu, li, de, jing, pian, shi, yang, fang...
# 187412    [ceng, lian, huo, san, jie, guo, jia, xin, wen...
# 187413                   [gu, xi, la, zuo, jia, zhi, yi, 。]
# Name: sentence, Length: 187414, dtype: object

# %%
len(s)
# Out:
# 187414

# %%
sum(s.apply(lambda x: len(x)))
# Out:
# 2700140

# %%
import matplotlib.pyplot as plt
audio_files = validated_df['path'].apply(lambda x: LARGE_16K_DIR / x).to_list()
energies = tqdm([librosa.feature.rms(y=torchaudio.load(f)[0].numpy().squeeze()).mean() for f in tqdm(audio_files)])
plt.hist(energies, bins=50)
plt.show()

# %%
import matplotlib.pyplot as plt
audio_files = validated_df['path'].apply(lambda x: LARGE_16K_DIR / x).to_list()
energies = [librosa.feature.rms(y=torchaudio.load(f)[0].numpy().squeeze()).mean() for f in audio_files]
plt.hist(energies, bins=50)
plt.show()

# %%
voice = 'common_voice_zh-CN_32892241.mp3'
print(f"sentence: {validated_df[validated_df['path'] == voice]['sentence'].iloc[0] }")
waveform16k, sample_rate = torchaudio.load(LARGE_16K_DIR / voice)
IPython.display.Audio(waveform16k, rate=16000)
# Out:
# sentence: 永宗大桥是座位于韩国仁川广域市连接永宗岛于朝鲜半岛内陆的自锚式悬索桥。
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
new_df = pd.read_csv('./large-corpus/prepped.csv')

# %%
new_df['transcript'] = new_df['transcript'].apply(json.loads)

# %%
new_df['transcript'] = new_df['transcript'].apply(lambda row: ' '.join(row))

# %%
new_df['sentence'] = new_df['sentence'].apply(lambda row: re.sub(r'[^\w]', '', row))

# %%
new_df.shape
# Out:
# (600247, 7)

# %%
new_df['transcript'][0]
# Out:
# 'mo shi zhong cai yang zi tai wan gui shan dao'

# %%
long = new_df[new_df['path'] == 'common_voice_zh-CN_32554902.mp3']

# %%
long
# Out:
#        Unnamed: 0                             path  \
# 60105       60105  common_voice_zh-CN_32554902.mp3
#
#                                               transcript  \
# 60105  ren ren you quan xiang shou wei wei chi ta ben...
#
#                                                 sentence  age gender accents
# 60105  人人有权享受为维持他本人和家属的健康和福利所需的生活水准包括食物衣着住房医疗和必要的社会服务...  NaN    NaN     NaN

# %%
print(lazy_pinyin(long['sentence']))
# Out:
# ['ren', 'ren', 'you', 'quan', 'xiang', 'shou', 'wei', 'wei', 'chi', 'ta', 'ben', 'ren', 'he', 'jia', 'shu', 'de', 'jian', 'kang', 'he', 'fu', 'li', 'suo', 'xu', 'de', 'sheng', 'huo', 'shui', 'zhun', 'bao', 'kuo', 'shi', 'wu', 'yi', 'zhe', 'zhu', 'fang', 'yi', 'liao', 'he', 'bi', 'yao', 'de', 'she', 'hui', 'fu', 'wu', 'zai', 'zao', 'dao', 'shi', 'ye', 'ji', 'bing', 'can', 'fei', 'shou', 'gua', 'shuai', 'lao', 'huo', 'zai', 'qi', 'ta', 'bu', 'neng', 'kong', 'zhi', 'de', 'qing', 'kuang', 'xia', 'sang', 'shi', 'mou', 'sheng', 'neng', 'li', 'shi', 'you', 'quan', 'xiang', 'shou', 'bao', 'zhang']

# %%
params = new_df[['path', 'transcript', 'sentence']].to_records(index=False).tolist()

# %%
import sys


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = bundle.get_model().to(device)
tokenizer = bundle.get_tokenizer()
aligner = bundle.get_aligner()

# ------------------------------------------------ #

def compute_alignments(waveform: torch.Tensor, transcript: List[str]):
  with torch.inference_mode():
    emission, _ = model(waveform.to(device))
    token_spans = aligner(emission[0], tokenizer(transcript))
  return emission, token_spans

def get_words(waveform, spans, num_frames):
  ratio = waveform.size(1) / num_frames

  return [
    waveform[:, int(ratio * span[0].start) : int(ratio * span[-1].end)]
    for span in spans
  ]

def driver(args):
  path, transcript, sentence = args

  try:
    waveform16k, _ = torchaudio.load(LARGE_16K_DIR / path)
    waveform16k = waveform16k[0:1].to(device)

    emission, token_spans = compute_alignments(waveform16k, transcript)
    num_frames = emission.size(1)

    words = get_words(waveform16k, token_spans, num_frames)

    # save each word tensor and store filenames
    word_filenames = []
    for i, word in enumerate(words):
      filename = f"{Path(path).stem}_word{i}.pt"
      filepath = WORD_TENSORS_DIR / filename
      torch.save(word.cpu(), filepath)
      word_filenames.append(str(filepath))

    return word_filenames, sentence

  except Exception as e:
    if "targets length is too long for CTC" in str(e):
      error_message = f"Alignment failed for {path}: {e}\n"
      sys.stderr.write(error_message)  # Print to stderr to avoid tqdm interference
      sys.stderr.flush()  # Ensure immediate writing to stderr

    else:
      sys.stderr.write(f"something else went wrong: {e}")  # Print to stderr to avoid tqdm interference
      sys.stderr.flush()  # Ensure immediate writing to stderr

    return None  # Ensures the pipeline doesn’t crash

# %%
small_val = validated_df[0:300]

# %%
small_val['sentence'] = small_val['sentence'].apply(lambda row: re.sub(r'[^\w]', '', row)) 

valid_pinyin = set("abcdefghijklmnopqrstuvwxyz")  # Allowed characters

def clean_pinyin(pinyin_list):
  return [''.join(c for c in word if c in valid_pinyin) for word in pinyin_list]

small_val['transcript'] = small_val['sentence'].apply(lambda row: clean_pinyin(lazy_pinyin(row)))


params_small = small_val[['path', 'transcript', 'sentence']].to_records(index=False).tolist()
# Out:
# /tmp/ipykernel_3032636/3586386153.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   small_val['sentence'] = small_val['sentence'].apply(lambda row: re.sub(r'[^\w]', '', row))
# /tmp/ipykernel_3032636/3586386153.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   small_val['transcript'] = small_val['sentence'].apply(lambda row: clean_pinyin(lazy_pinyin(row)))

# %%
segmentations = [driver(param) for param in tqdm(params_small) ]
# Out:
#  94%|█████████▍| 282/300 [00:14<00:00, 19.83it/s]Alignment failed for common_voice_zh-CN_33623781.mp3: targets length is too long for CTC. Found log_probs length: 95, targets length: 99, and number of repeats: 0
# 100%|██████████| 300/300 [00:15<00:00, 19.50it/s]

# %%
segmentations = [s for s in segmentations if s is not None]

# %%
test = pd.DataFrame(segmentations, columns=['word_files', 'sentence'])

# %%
test['transcript'] = test['sentence'].apply(lambda row: clean_pinyin(lazy_pinyin(row)))

# %%
test
# Out:
#                                             word_files  \
# 0    [/home/connor/audio/data/word_tensors/common_v...
# 1    [/home/connor/audio/data/word_tensors/common_v...
# 2    [/home/connor/audio/data/word_tensors/common_v...
# 3    [/home/connor/audio/data/word_tensors/common_v...
# 4    [/home/connor/audio/data/word_tensors/common_v...
# ..                                                 ...
# 294  [/home/connor/audio/data/word_tensors/common_v...
# 295  [/home/connor/audio/data/word_tensors/common_v...
# 296  [/home/connor/audio/data/word_tensors/common_v...
# 297  [/home/connor/audio/data/word_tensors/common_v...
# 298  [/home/connor/audio/data/word_tensors/common_v...
#
#                      sentence  \
# 0       黑身准裂腹鱼为辐鳍鱼纲鲤形目鲤科的其中一种
# 1                           否
# 2                 宋朝末年年间定居粉岭围
# 3          油小路通是京都市主要的南北向道路之一
# 4    富尔马诺夫出生在科斯特罗马省谢列达的一个农民家庭
# ..                        ...
# 294                         三
# 295                拉瓦莱特人口变化图示
# 296              这么閒还不快点去浪费时间
# 297                         七
# 298        埃尔特尔莱因是德国萨克森州的一个市镇
#
#                                             transcript
# 0    [hei, shen, zhun, lie, fu, yu, wei, fu, qi, yu...
# 1                                                [fou]
# 2    [song, chao, mo, nian, nian, jian, ding, ju, f...
# 3    [you, xiao, lu, tong, shi, jing, du, shi, zhu,...
# 4    [fu, er, ma, nuo, fu, chu, sheng, zai, ke, si,...
# ..                                                 ...
# 294                                              [san]
# 295    [la, wa, lai, te, ren, kou, bian, hua, tu, shi]
# 296  [zhe, me, xian, hai, bu, kuai, dian, qu, lang,...
# 297                                               [qi]
# 298  [ai, er, te, er, lai, yin, shi, de, guo, sa, k...
#
# [299 rows x 3 columns]

# %%
test.explode(['word_files', 'transcript'])
# Out:
#                                             word_files               sentence  \
# 0    /home/connor/audio/data/word_tensors/common_vo...  黑身准裂腹鱼为辐鳍鱼纲鲤形目鲤科的其中一种
# 0    /home/connor/audio/data/word_tensors/common_vo...  黑身准裂腹鱼为辐鳍鱼纲鲤形目鲤科的其中一种
# 0    /home/connor/audio/data/word_tensors/common_vo...  黑身准裂腹鱼为辐鳍鱼纲鲤形目鲤科的其中一种
# 0    /home/connor/audio/data/word_tensors/common_vo...  黑身准裂腹鱼为辐鳍鱼纲鲤形目鲤科的其中一种
# 0    /home/connor/audio/data/word_tensors/common_vo...  黑身准裂腹鱼为辐鳍鱼纲鲤形目鲤科的其中一种
# ..                                                 ...                    ...
# 298  /home/connor/audio/data/word_tensors/common_vo...     埃尔特尔莱因是德国萨克森州的一个市镇
# 298  /home/connor/audio/data/word_tensors/common_vo...     埃尔特尔莱因是德国萨克森州的一个市镇
# 298  /home/connor/audio/data/word_tensors/common_vo...     埃尔特尔莱因是德国萨克森州的一个市镇
# 298  /home/connor/audio/data/word_tensors/common_vo...     埃尔特尔莱因是德国萨克森州的一个市镇
# 298  /home/connor/audio/data/word_tensors/common_vo...     埃尔特尔莱因是德国萨克森州的一个市镇
#
#     transcript
# 0          hei
# 0         shen
# 0         zhun
# 0          lie
# 0           fu
# ..         ...
# 298         de
# 298         yi
# 298         ge
# 298        shi
# 298       zhen
#
# [4171 rows x 3 columns]

# %%
metadata_df = pd.DataFrame(segmentations, columns=['word_files', 'sentence'])

# %%
assert len(metadata_df['word_files'][0]) == len(lazy_pinyin(metadata_df['sentence'][0]))

# %%
sentences[:10]
# Out:
# ('模式种采样自台湾龟山岛',
#  '后者娶天之瓮主神',
#  '贝尔卢',
#  '日本与东帝汶的关系可追溯至第二次世界大战期间',
#  '单县各乡镇设有卫生院或医院',
#  '尤里二世当下便决定要在该地点建造大基捷日城',
#  '毛山鼠李为鼠李科鼠李属下的一个变种',
#  '遂吸收众多渴望消灾除难的人入道',
#  '毛山鼠李为鼠李科鼠李属下的一个变种',
#  '这项研究旨在了解一个地区的空间结构和性质')

# %% [markdown]
# # --------------------

# %%
df = pd.read_csv('./large-corpus/other.tsv', sep='\t')
# Out:
# /tmp/ipykernel_3032636/749438795.py:1: DtypeWarning: Columns (4,8,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./large-corpus/other.tsv', sep='\t')

# %%
df = df[['path', 'sentence', 'age', 'gender', 'accents']]

# %%
df.tail(10)
# Out:
#                                    path  \
# 600237  common_voice_zh-CN_41891242.mp3
# 600238  common_voice_zh-CN_41891243.mp3
# 600239  common_voice_zh-CN_41891244.mp3
# 600240  common_voice_zh-CN_41891245.mp3
# 600241  common_voice_zh-CN_41891246.mp3
# 600242  common_voice_zh-CN_41891247.mp3
# 600243  common_voice_zh-CN_41891248.mp3
# 600244  common_voice_zh-CN_41891249.mp3
# 600245  common_voice_zh-CN_41907107.mp3
# 600246  common_voice_zh-CN_41907108.mp3
#
#                                                  sentence       age gender  \
# 600237                                     它是西半球最大的科学博物馆。  thirties    NaN
# 600238  总的来说，美国从政策和制度上在乌克兰开展反对俄罗斯的活动包括经济援助、军事援助、外交压力、信...  thirties    NaN
# 600239                             智深道：“胡说，这等一个大去处，不信没斋粮。  thirties    NaN
# 600240                                 輕輕敲醒沉睡的心靈，慢慢張開你地眼睛  thirties    NaN
# 600241                                       中华民国主权属于国民全体  thirties    NaN
# 600242                                             炫家军来也！  thirties    NaN
# 600243                             索伊贝尔斯多尔夫是德国巴伐利亚州的一个市镇。  thirties    NaN
# 600244  情报侦察：乌克兰军队通过加强情报侦察工作，及时获得敌方无人机的动向和部署情况，从而能够提前采...  thirties    NaN
# 600245                                                  三       NaN    NaN
# 600246                                  数据集包含真实、仿真和干净的录音。       NaN    NaN
#
#            accents
# 600237  出生地：51 四川省
# 600238  出生地：51 四川省
# 600239  出生地：51 四川省
# 600240  出生地：51 四川省
# 600241  出生地：51 四川省
# 600242  出生地：51 四川省
# 600243  出生地：51 四川省
# 600244  出生地：51 四川省
# 600245         NaN
# 600246         NaN

# %%
df['sentence'] = df['sentence'].apply(lambda row: re.sub(r'[^\w]', '', row))

# %%
df['transcript'] = df['sentence'].progress_apply(lambda row: [ "".join(lazy_pinyin(word)) for word in list(jieba.cut(row))])
# Out:
# Processing data: 100%|██████████| 600247/600247 [01:34<00:00, 6358.20it/s]

# %%
df['transcript'][0:5]
# Out:
# 0      [moshi, zhong, caiyang, zi, taiwan, guishandao]
# 1               [houzhe, qu, tian, zhi, weng, zhushen]
# 2                                          [beier, lu]
# 3    [riben, yu, dongdiwen, de, guanxi, kezhuisu, z...
# 4    [danxian, gexiangzhen, sheyou, weishengyuan, h...
# Name: transcript, dtype: object

# %%
long = df[df['path'] == 'common_voice_zh-CN_32554902.mp3']

# %%
# Out:
# 241227    三甲村战斗是发生在中国抗日战争百团大战期间涞灵战役中的一次战斗
# Name: sentence, dtype: object

# %%
voice = 'common_voice_zh-CN_33411896.mp3'
print(f"sentence: {validated_df[validated_df['path'] == voice]['sentence'].iloc[0] }")
waveform16k, sample_rate = torchaudio.load(LARGE_16K_DIR / voice)
IPython.display.Audio(waveform16k, rate=16000)
# Out:
# sentence: 黑身准裂腹鱼为辐鳍鱼纲鲤形目鲤科的其中一种。
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
torchaudio.load(LARGE_16K_DIR / df['path'][0])
# Out:
# (tensor([[-1.1826e-05, -3.8991e-05, -1.4978e-05,  ..., -1.4315e-04,
#           -1.3605e-05,  2.1167e-05]]),
#  16000)

# %%
device = 'cuda'

# %%
model = bundle.get_model(with_star=True)
model.to(device)

tokenizer = bundle.get_tokenizer()
aligner = bundle.get_aligner()

# %%
def compute_alignments(waveform: torch.Tensor, transcript: List[str]):
    with torch.inference_mode():
        emission, _ = model(waveform.to(device))
        token_spans = aligner(emission[0], tokenizer(transcript))
    return emission, token_spans

# %%
# Compute average score weighted by the span length
def _score(spans):
    return sum(s.score * len(s) for s in spans) / sum(len(s) for s in spans)


def plot_alignments(waveform, token_spans, emission, transcript, sample_rate=bundle.sample_rate):
    ratio = waveform.size(1) / emission.size(1) / sample_rate

    fig, axes = plt.subplots(2, 1)
    axes[0].imshow(emission[0].detach().cpu().T, aspect="auto")
    axes[0].set_title("Emission")
    axes[0].set_xticks([])

    axes[1].specgram(waveform[0], Fs=sample_rate)
    for t_spans, chars in zip(token_spans, transcript):
        t0, t1 = t_spans[0].start, t_spans[-1].end
        axes[0].axvspan(t0 - 0.5, t1 - 0.5, facecolor="None", hatch="/", edgecolor="white")
        axes[1].axvspan(ratio * t0, ratio * t1, facecolor="None", hatch="/", edgecolor="white")
        axes[1].annotate(f"{_score(t_spans):.2f}", (ratio * t0, sample_rate * 0.51), annotation_clip=False)

        for span, char in zip(t_spans, chars):
            t0 = span.start * ratio
            axes[1].annotate(char, (t0, sample_rate * 0.55), annotation_clip=False)

    axes[1].set_xlabel("time [second]")
    fig.tight_layout()

# %%
def preview_word(waveform, spans, num_frames, transcript, sample_rate=bundle.sample_rate):
    ratio = waveform.size(1) / num_frames
    x0 = int(ratio * spans[0].start)
    x1 = int(ratio * spans[-1].end)
    print(f"{transcript} ({_score(spans):.2f}): {x0 / sample_rate:.3f} - {x1 / sample_rate:.3f} sec")
    segment = waveform[:, x0:x1]
    return IPython.display.Audio(segment.numpy(), rate=sample_rate)

# %%
long['sentence'].to_string(index=False)
# Out:
# '人人有权享受为维持他本人和家属的健康和福利所需的生活水准包括食物衣着住房医疗和必要的社会服务在...'

# %%
raw_text = re.sub(r'[^\w]', '', long['sentence'].to_string(index=False))

# %%
transcript = lazy_pinyin(raw_text)

# %%
waveform16k, sample_rate = torchaudio.load(LARGE_16K_DIR / df['path'][0])

# %%
waveform16k_long, sample_rate = torchaudio.load(LARGE_16K_DIR / long['path'].to_string(index=False))

# %%
transcript = long['transcript'].iloc[0]

# %%
len(transcript)
# Out:
# 49

# %%
sum([ len(item) for item in tokenizer(transcript)])
# Out:
# 261

# %%
transcript
# Out:
# ['renren',
#  'youquan',
#  'xiangshou',
#  'wei',
#  'weichi',
#  'ta',
#  'benren',
#  'he',
#  'jiashu',
#  'de',
#  'jiankang',
#  'he',
#  'fuli',
#  'suo',
#  'xu',
#  'de',
#  'shenghuoshuizhun',
#  'baokuo',
#  'shiwu',
#  'yizhuo',
#  'zhufang',
#  'yiliao',
#  'he',
#  'biyao',
#  'de',
#  'shehui',
#  'fuwu',
#  'zai',
#  'zaodao',
#  'shiye',
#  'jibing',
#  'canfei',
#  'shougua',
#  'shuailao',
#  'huo',
#  'zai',
#  'qita',
#  'buneng',
#  'kongzhi',
#  'de',
#  'qingkuang',
#  'xia',
#  'sangshi',
#  'mousheng',
#  'nengli',
#  'shi',
#  'youquan',
#  'xiangshou',
#  'baozhang']

# %%
tokenizer(transcript)
# Out:
# [[9, 3, 4, 9, 3, 4],
#  [16, 5, 6, 26, 6, 1, 4],
#  [27, 2, 1, 4, 14, 8, 15, 5, 6],
#  [19, 3, 2],
#  [19, 3, 2, 20, 15, 2],
#  [7, 1],
#  [17, 3, 4, 9, 3, 4],
#  [15, 3],
#  [22, 2, 1, 8, 15, 6],
#  [13, 3],
#  [22, 2, 1, 4, 11, 1, 4, 14],
#  [15, 3],
#  [24, 6, 12, 2],
#  [8, 6, 5],
#  [27, 6],
#  [13, 3],
#  [8, 15, 3, 4, 14, 15, 6, 5, 8, 15, 6, 2, 23, 15, 6, 4],
#  [17, 1, 5, 11, 6, 5],
#  [8, 15, 2, 19, 6],
#  [16, 2, 23, 15, 6, 5],
#  [23, 15, 6, 24, 1, 4, 14],
#  [16, 2, 12, 2, 1, 5],
#  [15, 3],
#  [17, 2, 16, 1, 5],
#  [13, 3],
#  [8, 15, 3, 15, 6, 2],
#  [24, 6, 19, 6],
#  [23, 1, 2],
#  [23, 1, 5, 13, 1, 5],
#  [8, 15, 2, 16, 3],
#  [22, 2, 17, 2, 4, 14],
#  [20, 1, 4, 24, 3, 2],
#  [8, 15, 5, 6, 14, 6, 1],
#  [8, 15, 6, 1, 2, 12, 1, 5],
#  [15, 6, 5],
#  [23, 1, 2],
#  [26, 2, 7, 1],
#  [17, 6, 4, 3, 4, 14],
#  [11, 5, 4, 14, 23, 15, 2],
#  [13, 3],
#  [26, 2, 4, 14, 11, 6, 1, 4, 14],
#  [27, 2, 1],
#  [8, 1, 4, 14, 8, 15, 2],
#  [10, 5, 6, 8, 15, 3, 4, 14],
#  [4, 3, 4, 14, 12, 2],
#  [8, 15, 2],
#  [16, 5, 6, 26, 6, 1, 4],
#  [27, 2, 1, 4, 14, 8, 15, 5, 6],
#  [17, 1, 5, 23, 15, 1, 4, 14]]

# %%
waveform16k = waveform16k_long[0:1]

# %%
with torch.inference_mode():
    emission, _ = model(waveform16k.to(device))

# %%
LABELS = bundle.get_labels(star=None)
DICTIONARY = bundle.get_dict(star=None)

# %%
tokenized_transcript = [DICTIONARY[c] for word in transcript for c in word]

# %%
for t in tokenized_transcript:
    print(t, end=" ")
print()
# Out:
# 9 3 4 9 3 4 16 5 6 26 6 1 4 27 2 1 4 14 8 15 5 6 19 3 2 19 3 2 20 15 2 7 1 17 3 4 9 3 4 15 3 22 2 1 8 15 6 13 3 22 2 1 4 11 1 4 14 15 3 24 6 12 2 8 6 5 27 6 13 3 8 15 3 4 14 15 6 5 8 15 6 2 23 15 6 4 17 1 5 11 6 5 8 15 2 19 6 16 2 23 15 6 5 23 15 6 24 1 4 14 16 2 12 2 1 5 15 3 17 2 16 1 5 13 3 8 15 3 15 6 2 24 6 19 6 23 1 2 23 1 5 13 1 5 8 15 2 16 3 22 2 17 2 4 14 20 1 4 24 3 2 8 15 5 6 14 6 1 8 15 6 1 2 12 1 5 15 6 5 23 1 2 26 2 7 1 17 6 4 3 4 14 11 5 4 14 23 15 2 13 3 26 2 4 14 11 6 1 4 14 27 2 1 8 1 4 14 8 15 2 10 5 6 8 15 3 4 14 4 3 4 14 12 2 8 15 2 16 5 6 26 6 1 4 27 2 1 4 14 8 15 5 6 17 1 5 23 15 1 4 14

# %%
def align(emission, tokens):
    targets = torch.tensor([tokens], dtype=torch.int32, device=device)
    alignments, scores = F.forced_align(emission, targets, blank=0)

    alignments, scores = alignments[0], scores[0]  # remove batch dimension for simplicity
    scores = scores.exp()  # convert back to probability
    return alignments, scores


aligned_tokens, alignment_scores = align(emission, tokenized_transcript)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[112], line 10
#       6     scores = scores.exp()  # convert back to probability
#       7     return alignments, scores
# ---> 10 aligned_tokens, alignment_scores = align(emission, tokenized_transcript)
#
# Cell In[112], line 3, in align(emission, tokens)
#       1 def align(emission, tokens):
#       2     targets = torch.tensor([tokens], dtype=torch.int32, device=device)
# ----> 3     alignments, scores = F.forced_align(emission, targets, blank=0)
#       5     alignments, scores = alignments[0], scores[0]  # remove batch dimension for simplicity
#       6     scores = scores.exp()  # convert back to probability
#
# File ~/miniconda3/envs/sound/lib/python3.11/site-packages/torchaudio/functional/_alignment.py:72, in forced_align(log_probs, targets, input_lengths, target_lengths, blank)
#      69 assert input_lengths is not None
#      70 assert target_lengths is not None
# ---> 72 paths, scores = torch.ops.torchaudio.forced_align(log_probs, targets, input_lengths, target_lengths, blank)
#      73 return paths, scores
#
# File ~/miniconda3/envs/sound/lib/python3.11/site-packages/torch/_ops.py:1116, in OpOverloadPacket.__call__(self, *args, **kwargs)
#    1114 if self._has_torchbind_op_overload and _must_dispatch_in_python(args, kwargs):
#    1115     return _call_overload_packet_from_python(self, args, kwargs)
# -> 1116 return self._op(*args, **(kwargs or {}))
#
# RuntimeError: targets length is too long for CTC. Found log_probs length: 210, targets length: 261, and number of repeats: 0

# %%
  emission, token_spans = compute_alignments(waveform16k, transcript)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 emission, token_spans = compute_alignments(waveform16k, transcript)
#
# Cell In[77], line 4, in compute_alignments(waveform, transcript)
#       2 with torch.inference_mode():
#       3     emission, _ = model(waveform.to(device))
# ----> 4     token_spans = aligner(emission[0], tokenizer(transcript))
#       5 return emission, token_spans
#
# File ~/miniconda3/envs/sound/lib/python3.11/site-packages/torchaudio/pipelines/_wav2vec2/aligner.py:85, in Aligner.__call__(self, emission, tokens)
#      82 if emission.ndim != 2:
#      83     raise ValueError(f"The input emission must be 2D. Found: {emission.shape}")
# ---> 85 aligned_tokens, scores = _align_emission_and_tokens(emission, _flatten(tokens), self.blank)
#      86 spans = F.merge_tokens(aligned_tokens, scores)
#      87 return _unflatten(spans, [len(ts) for ts in tokens])
#
# File ~/miniconda3/envs/sound/lib/python3.11/site-packages/torchaudio/pipelines/_wav2vec2/aligner.py:40, in _align_emission_and_tokens(emission, tokens, blank)
#      37 emission = emission.unsqueeze(0)
#      38 targets = torch.tensor([tokens], dtype=torch.int32, device=device)
# ---> 40 aligned_tokens, scores = F.forced_align(emission, targets, blank=blank)
#      42 scores = scores.exp()  # convert back to probability
#      43 aligned_tokens, scores = aligned_tokens[0], scores[0]  # remove batch dimension
#
# File ~/miniconda3/envs/sound/lib/python3.11/site-packages/torchaudio/functional/_alignment.py:72, in forced_align(log_probs, targets, input_lengths, target_lengths, blank)
#      69 assert input_lengths is not None
#      70 assert target_lengths is not None
# ---> 72 paths, scores = torch.ops.torchaudio.forced_align(log_probs, targets, input_lengths, target_lengths, blank)
#      73 return paths, scores
#
# File ~/miniconda3/envs/sound/lib/python3.11/site-packages/torch/_ops.py:1116, in OpOverloadPacket.__call__(self, *args, **kwargs)
#    1114 if self._has_torchbind_op_overload and _must_dispatch_in_python(args, kwargs):
#    1115     return _call_overload_packet_from_python(self, args, kwargs)
# -> 1116 return self._op(*args, **(kwargs or {}))
#
# RuntimeError: targets length is too long for CTC. Found log_probs length: 210, targets length: 261, and number of repeats: 0

# %%
num_frames = emission.size(1)

# %%
IPython.display.Audio(waveform16k, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plot_alignments(waveform16k, token_spans, emission, transcript)
print("Raw Transcript: ", raw_text)
print("Normalized Transcript: ", transcript)
IPython.display.Audio(waveform16k, rate=16000)
# Out:
# Raw Transcript:  模式种采样自台湾龟山岛
# Normalized Transcript:  ['mo', 'shi', 'zhong', 'cai', 'yang', 'zi', 'tai', 'wan', 'gui', 'shan', 'dao']
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
preview_word(waveform16k, token_spans[0], num_frames, transcript[0])
# Out:
# mo (0.98): 0.523 - 0.624 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
preview_word(waveform16k, token_spans[1], num_frames, transcript[1])
# Out:
# shi (0.94): 0.745 - 0.825 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def get_words(waveform, spans, num_frames, transcript, sample_rate=bundle.sample_rate):
  words = []

  for span, word in zip(spans, transcript):
    ratio = waveform.size(1) / num_frames
    x0 = int(ratio * span[0].start)
    x1 = int(ratio * span[-1].end)
    # print(f"{word} ({_score(span):.2f}): {x0 / sample_rate:.3f} - {x1 / sample_rate:.3f} sec")
    segment = waveform[:, x0:x1]

    words.append(segment.numpy())
  
  return words

# %%
get_words(waveform16k, token_spans, num_frames, transcript)
# Out:
# [array([[ 0.0008602 ,  0.00152547,  0.00146088, ..., -0.12834494,
#          -0.17637731, -0.21712922]], dtype=float32),
#  array([[0.05190656, 0.0598904 , 0.07408149, ..., 0.03356873, 0.03668607,
#          0.04070076]], dtype=float32),
#  array([[0.0181216 , 0.01834476, 0.01048384, ..., 0.02646755, 0.03330116,
#          0.04097961]], dtype=float32),
#  array([[-0.00456466, -0.00209737, -0.00218755, ...,  0.05800441,
#           0.05843846,  0.05498751]], dtype=float32),
#  array([[-0.01578683, -0.00539359,  0.00030392, ..., -0.03163794,
#          -0.04327597, -0.05283451]], dtype=float32),
#  array([[ 0.00092188,  0.00112764,  0.00146424, ...,  0.02488283,
#           0.00154205, -0.03782079]], dtype=float32),
#  array([[-0.00292676, -0.00162197, -0.00289358, ..., -0.17404167,
#          -0.16074258, -0.14482822]], dtype=float32),
#  array([[-0.06909257, -0.08633623, -0.09417263, ..., -0.0747348 ,
#          -0.0637566 , -0.05508458]], dtype=float32),
#  array([[-0.02763853, -0.02779888, -0.02619934, ..., -0.03387009,
#          -0.04196569, -0.05878041]], dtype=float32),
#  array([[ 0.01358786, -0.00465931, -0.01310309, ...,  0.10732409,
#           0.10032883,  0.09150387]], dtype=float32),
#  array([[0.00626623, 0.00435528, 0.00215785, ..., 0.00254698, 0.0027387 ,
#          0.00332146]], dtype=float32)]

# %%
def get_words(waveform, spans, num_frames) -> List[np.ndarray]:
  words = []

  for span in spans:
    ratio = waveform.size(1) / num_frames
    x0 = int(ratio * span[0].start)
    x1 = int(ratio * span[-1].end)
    segment = waveform[:, x0:x1]

    words.append(segment)
  
  return words

# %%
def driver(path, sentence):
  raw_text = re.sub(r'[^\w]', '', sentence)
  transcript = lazy_pinyin(raw_text)

  waveform48k, sample_rate = torchaudio.load(LARGE_MP3_DIR / path)

  resampler = T.Resample(orig_freq=48000, new_freq=16000)
  waveform16k = resampler(waveform48k[0:1])

  emission, token_spans = compute_alignments(waveform16k, transcript)
  num_frames = emission.size(1)

  words = get_words(waveform16k, token_spans, num_frames)

  return words

# %%
df.shape
# Out:
# (600247, 13)

# %%
samll = df[:100]

# %%
samll['segmented_audio'] = samll.progress_apply(lambda row: driver(row['path'], row['sentence']), axis=1)
# Out:
# Processing data: 100%|██████████| 100/100 [00:36<00:00,  2.74it/s]
# /var/folders/mz/73jxv48x3tb6l6wc7_wvd7t00000gn/T/ipykernel_26215/807193021.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   samll['segmented_audio'] = samll.progress_apply(lambda row: driver(row['path'], row['sentence']), axis=1)

# %%
from utils.data_processing import breakdown_pinyin

# %%
samll['pinyin_breakdown'] = samll['sentence'].progress_apply(breakdown_pinyin)
# Out:
# Processing data: 100%|██████████| 100/100 [00:00<00:00, 1942.20it/s]
# /var/folders/mz/73jxv48x3tb6l6wc7_wvd7t00000gn/T/ipykernel_26215/844437691.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   samll['pinyin_breakdown'] = samll['sentence'].progress_apply(breakdown_pinyin)

# %%
samll['character'] = samll['sentence'].apply(lambda row: [char for char in re.sub(r'[^\w]', '', row)])
# Out:
# /var/folders/mz/73jxv48x3tb6l6wc7_wvd7t00000gn/T/ipykernel_26215/3264336854.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   samll['character'] = samll['sentence'].apply(lambda row: [char for char in re.sub(r'[^\w]', '', row)])

# %%
len(samll['segmented_audio'][0]) == len(samll['pinyin_breakdown'][0])
# Out:
# True

# %%
mask = samll.apply(lambda row: len(row['character']) == len(row['pinyin_breakdown']), axis=1)

# %%
samll.explode(['segmented_audio', 'character', 'pinyin_breakdown'], ignore_index=True)
# Out:
#                                               client_id  \
# 0     25bc975d06200b7b1c9135db090561cb0d9b28d172e51c...
# 1     25bc975d06200b7b1c9135db090561cb0d9b28d172e51c...
# 2     25bc975d06200b7b1c9135db090561cb0d9b28d172e51c...
# 3     25bc975d06200b7b1c9135db090561cb0d9b28d172e51c...
# 4     25bc975d06200b7b1c9135db090561cb0d9b28d172e51c...
# ...                                                 ...
# 1626  56d138a29f7850e806c48289e68a284506907d6d3ff2d7...
# 1627  56d138a29f7850e806c48289e68a284506907d6d3ff2d7...
# 1628  56d138a29f7850e806c48289e68a284506907d6d3ff2d7...
# 1629  56d138a29f7850e806c48289e68a284506907d6d3ff2d7...
# 1630  56d138a29f7850e806c48289e68a284506907d6d3ff2d7...
#
#                                  path  \
# 0     common_voice_zh-CN_19703883.mp3
# 1     common_voice_zh-CN_19703883.mp3
# 2     common_voice_zh-CN_19703883.mp3
# 3     common_voice_zh-CN_19703883.mp3
# 4     common_voice_zh-CN_19703883.mp3
# ...                               ...
# 1626  common_voice_zh-CN_22050256.mp3
# 1627  common_voice_zh-CN_22050256.mp3
# 1628  common_voice_zh-CN_22050256.mp3
# 1629  common_voice_zh-CN_22050256.mp3
# 1630  common_voice_zh-CN_22050256.mp3
#
#                                             sentence_id  \
# 0     33bf426e7162122b062710c1aee44949efea3fef159bbb...
# 1     33bf426e7162122b062710c1aee44949efea3fef159bbb...
# 2     33bf426e7162122b062710c1aee44949efea3fef159bbb...
# 3     33bf426e7162122b062710c1aee44949efea3fef159bbb...
# 4     33bf426e7162122b062710c1aee44949efea3fef159bbb...
# ...                                                 ...
# 1626  60d9a59e86d5fec6814ab4eba0f29734973ed4980cd838...
# 1627  60d9a59e86d5fec6814ab4eba0f29734973ed4980cd838...
# 1628  60d9a59e86d5fec6814ab4eba0f29734973ed4980cd838...
# 1629  60d9a59e86d5fec6814ab4eba0f29734973ed4980cd838...
# 1630  60d9a59e86d5fec6814ab4eba0f29734973ed4980cd838...
#
#                     sentence sentence_domain  up_votes  down_votes       age  \
# 0               模式种采样自台湾龟山岛。             NaN         1           0  thirties
# 1               模式种采样自台湾龟山岛。             NaN         1           0  thirties
# 2               模式种采样自台湾龟山岛。             NaN         1           0  thirties
# 3               模式种采样自台湾龟山岛。             NaN         1           0  thirties
# 4               模式种采样自台湾龟山岛。             NaN         1           0  thirties
# ...                      ...             ...       ...         ...       ...
# 1626  会面导致穆夫提被巴基斯坦一个宗教委员会停职。             NaN         0           0  thirties
# 1627  会面导致穆夫提被巴基斯坦一个宗教委员会停职。             NaN         0           0  thirties
# 1628  会面导致穆夫提被巴基斯坦一个宗教委员会停职。             NaN         0           0  thirties
# 1629  会面导致穆夫提被巴基斯坦一个宗教委员会停职。             NaN         0           0  thirties
# 1630  会面导致穆夫提被巴基斯坦一个宗教委员会停职。             NaN         0           0  thirties
#
#                gender     accents  variant locale segment  \
# 0     female_feminine  出生地：31 上海市      NaN  zh-CN     NaN
# 1     female_feminine  出生地：31 上海市      NaN  zh-CN     NaN
# 2     female_feminine  出生地：31 上海市      NaN  zh-CN     NaN
# 3     female_feminine  出生地：31 上海市      NaN  zh-CN     NaN
# 4     female_feminine  出生地：31 上海市      NaN  zh-CN     NaN
# ...               ...         ...      ...    ...     ...
# 1626   male_masculine  出生地：22 吉林省      NaN  zh-CN     NaN
# 1627   male_masculine  出生地：22 吉林省      NaN  zh-CN     NaN
# 1628   male_masculine  出生地：22 吉林省      NaN  zh-CN     NaN
# 1629   male_masculine  出生地：22 吉林省      NaN  zh-CN     NaN
# 1630   male_masculine  出生地：22 吉林省      NaN  zh-CN     NaN
#
#                                         segmented_audio  pinyin_breakdown  \
# 0     [[tensor(0.0009), tensor(0.0015), tensor(0.001...         (m, o, 2)
# 1     [[tensor(0.0519), tensor(0.0599), tensor(0.074...        (sh, i, 4)
# 2     [[tensor(0.0181), tensor(0.0183), tensor(0.010...      (zh, ong, 3)
# 3     [[tensor(-0.0046), tensor(-0.0021), tensor(-0....        (c, ai, 3)
# 4     [[tensor(-0.0158), tensor(-0.0054), tensor(0.0...  (EMPTY, iang, 4)
# ...                                                 ...               ...
# 1626  [[tensor(-0.0174), tensor(-0.0240), tensor(-0....   (EMPTY, uei, 3)
# 1627  [[tensor(-0.0063), tensor(-0.0415), tensor(-0....   (EMPTY, van, 2)
# 1628  [[tensor(0.0217), tensor(0.0189), tensor(0.014...       (h, uei, 4)
# 1629  [[tensor(0.0009), tensor(-0.0043), tensor(-0.0...       (t, ing, 2)
# 1630  [[tensor(-0.0017), tensor(-0.0026), tensor(-0....        (zh, i, 2)
#
#      character
# 0            模
# 1            式
# 2            种
# 3            采
# 4            样
# ...        ...
# 1626         委
# 1627         员
# 1628         会
# 1629         停
# 1630         职
#
# [1631 rows x 16 columns]

# %%
samll[['path', 'sentence']].to_records(index=False).tolist()
# Out:
# [('common_voice_zh-CN_19703883.mp3', '模式种采样自台湾龟山岛。'),
#  ('common_voice_zh-CN_19706151.mp3', '后者娶天之瓮主神。'),
#  ('common_voice_zh-CN_19961025.mp3', '贝尔卢。'),
#  ('common_voice_zh-CN_20051292.mp3', '日本与东帝汶的关系可追溯至第二次世界大战期间。'),
#  ('common_voice_zh-CN_20051309.mp3', '单县各乡镇设有卫生院或医院。'),
#  ('common_voice_zh-CN_20070076.mp3', '尤里二世当下便决定要在该地点建造大基捷日城。'),
#  ('common_voice_zh-CN_20070223.mp3', '毛山鼠李为鼠李科鼠李属下的一个变种。'),
#  ('common_voice_zh-CN_20070263.mp3', '遂吸收众多渴望消灾除难的人入道。'),
#  ('common_voice_zh-CN_20070488.mp3', '毛山鼠李为鼠李科鼠李属下的一个变种。'),
#  ('common_voice_zh-CN_20163037.mp3', '这项研究旨在了解一个地区的空间结构和性质。'),
#  ('common_voice_zh-CN_20163057.mp3', '驯养的沙特瞪羚的基因分析显示它们有可能是不同的物种或混种。'),
#  ('common_voice_zh-CN_20220279.mp3', '后其家移居台湾台北市。'),
#  ('common_voice_zh-CN_20359866.mp3', '本条目记载了有关日本的妖怪。'),
#  ('common_voice_zh-CN_20359996.mp3', '阿丽安萝德中扮演了其最重要的角色。'),
#  ('common_voice_zh-CN_20391561.mp3', '格里梅尔斯豪森是德国图林根州的一个市镇。'),
#  ('common_voice_zh-CN_20391684.mp3', '厌食症确诊的必要条件为明显过低的体重。'),
#  ('common_voice_zh-CN_20409535.mp3', '请勿摄影、饮食、吸烟'),
#  ('common_voice_zh-CN_20409575.mp3', '这意味着清党行动使得中国国民党党务系统大换血。'),
#  ('common_voice_zh-CN_20499197.mp3', '现已被撤销。'),
#  ('common_voice_zh-CN_20737994.mp3', '该物种的模式产地在南京。'),
#  ('common_voice_zh-CN_20778962.mp3', '毕业于山东大学有机化学专业。'),
#  ('common_voice_zh-CN_20867081.mp3', '中华人民共和国第四机械工业部。'),
#  ('common_voice_zh-CN_20867196.mp3', '中华人民共和国第四机械工业部。'),
#  ('common_voice_zh-CN_20890152.mp3', '通过在钢材表面电镀锌而制成。'),
#  ('common_voice_zh-CN_20924369.mp3', '拉东人口变化图示'),
#  ('common_voice_zh-CN_20924417.mp3', '其总部设在匈牙利布达佩斯。'),
#  ('common_voice_zh-CN_20939713.mp3', '这亦是球队在洲际比赛的第一个冠军。'),
#  ('common_voice_zh-CN_21162572.mp3', '中国大陆的歌迷称她为美丽的高山族护士歌手。'),
#  ('common_voice_zh-CN_21208624.mp3', '她的研究彻底改变了宇宙学家对宇宙的了解和模型建构。'),
#  ('common_voice_zh-CN_21208625.mp3', '然而在建成混凝土核心部分后由于资金问题而停建。'),
#  ('common_voice_zh-CN_21220708.mp3', '著名演员周采芹是她的姑姑。'),
#  ('common_voice_zh-CN_21223411.mp3', '所有矩阵群是某个一般线性群的子群。'),
#  ('common_voice_zh-CN_21238303.mp3', '沙尔穆瓦尔。'),
#  ('common_voice_zh-CN_21238308.mp3', '拉登堡出生于德国曼海姆一个著名的犹太人家庭。'),
#  ('common_voice_zh-CN_21239427.mp3', '绒毛折颚蟹为方蟹科折颚蟹属的动物。'),
#  ('common_voice_zh-CN_21239588.mp3', '服务于沿线的市区内工厂企业。'),
#  ('common_voice_zh-CN_21273009.mp3', '巴莫崖豆藤'),
#  ('common_voice_zh-CN_21353974.mp3', '元世祖以后只有得到策宝的皇后才算正宫皇后。'),
#  ('common_voice_zh-CN_21356031.mp3', '元世祖以后只有得到策宝的皇后才算正宫皇后。'),
#  ('common_voice_zh-CN_21402081.mp3', '被谭鑫培倚为左右手。'),
#  ('common_voice_zh-CN_21402644.mp3', '被谭鑫培倚为左右手。'),
#  ('common_voice_zh-CN_21562812.mp3', '俄罗斯亦引入凤眼蓝作为处理生活污水和工业废水。'),
#  ('common_voice_zh-CN_21602239.mp3', '因此黎质的计谋失败。'),
#  ('common_voice_zh-CN_21602397.mp3', '以下是一个范例。'),
#  ('common_voice_zh-CN_21602420.mp3', '韦瑟比担任州长期间的另一项标志性成就是大幅改善了肯塔基州的教育系统。'),
#  ('common_voice_zh-CN_21788384.mp3', '二战时参加过日军入侵法属印度支那和香港攻防战。'),
#  ('common_voice_zh-CN_21788391.mp3', '埃塞俄比亚很直接的对意大利印象深刻的就是海关在这里上班。'),
#  ('common_voice_zh-CN_21788399.mp3', '他们和他们的追随者被称为爵士迷。'),
#  ('common_voice_zh-CN_21788403.mp3', '它被藏在一个苏联送给美国驻莫斯科大使的礼物中。'),
#  ('common_voice_zh-CN_21788424.mp3', '肉叶鞘蕊花为唇形科鞘蕊花属下的一个种。'),
#  ('common_voice_zh-CN_21788429.mp3', '当地最著名的巨岩是山羊岩。'),
#  ('common_voice_zh-CN_21788446.mp3', '埃尔茨城堡是德国的一座中世纪时期城堡。'),
#  ('common_voice_zh-CN_21788449.mp3', '炮长位于单人炮塔内部左侧。'),
#  ('common_voice_zh-CN_21788452.mp3', '除了可用内存的限制之外没有内核对象创建数量上限。'),
#  ('common_voice_zh-CN_21788460.mp3', '红叶藤为牛栓藤科红叶藤属的植物。'),
#  ('common_voice_zh-CN_21788467.mp3', '艺术世界也越来越注重艺术上的象征法。'),
#  ('common_voice_zh-CN_21788484.mp3', '大致与朝鲜半岛南部海岸线平行。'),
#  ('common_voice_zh-CN_21788489.mp3', '它是一个几乎必然是零的随机变数的累积分布函数。'),
#  ('common_voice_zh-CN_21792812.mp3', '荷电粒子炮是指电离的带电粒子利用加速器将其加速打出以其破坏敌械的武器。'),
#  ('common_voice_zh-CN_21792858.mp3', '杰佛里也许将这个名字取自凯尔李尔。'),
#  ('common_voice_zh-CN_21792875.mp3', '毕业于广西自治区党委党校党政管理专业。'),
#  ('common_voice_zh-CN_21792895.mp3', '地热能则是因为行星核心内放射性衰变或吸积加热而形成。'),
#  ('common_voice_zh-CN_21792902.mp3', '中国人民大学文学院教授潘天强对该片持负面态度。'),
#  ('common_voice_zh-CN_21792920.mp3', '蓝德尔星孔珊瑚为轴孔珊瑚科星孔珊瑚下的一个种。'),
#  ('common_voice_zh-CN_21792951.mp3', '曼秀雷敦软膏仍是由乐敦制药旗下曼秀雷敦公司生产的为原创产品。'),
#  ('common_voice_zh-CN_21792998.mp3', '这一类产品可以在硬体商店或线上商店购得。'),
#  ('common_voice_zh-CN_21793010.mp3', '汉武帝建元五年改山划国为山阳郡。'),
#  ('common_voice_zh-CN_21793013.mp3', '曾加盟香港亚洲电视及无线电视。'),
#  ('common_voice_zh-CN_21793030.mp3', '坦伯顿爵士希望以此来提升英国管理学的水平。'),
#  ('common_voice_zh-CN_21793032.mp3', '当两个水果跨度过大时系统会自动加速且背景会有红色的闪光效果。'),
#  ('common_voice_zh-CN_21793035.mp3', '这些细胞的作用在于识别和消灭可能导致感染的病原体。'),
#  ('common_voice_zh-CN_21793038.mp3', '僧侣的被提名人必须要有国民议会议长的批准。'),
#  ('common_voice_zh-CN_21946103.mp3', '德木寺是位于中国西藏自治区林芝市巴宜区米瑞乡的一座藏传佛教格鲁派寺院。'),
#  ('common_voice_zh-CN_21949445.mp3', '翌季史托迪尔没有获一队选派上阵。'),
#  ('common_voice_zh-CN_21950758.mp3', '翌季史托迪尔没有获一队选派上阵。'),
#  ('common_voice_zh-CN_21955807.mp3', '他被控欺诈破产并被通缉。'),
#  ('common_voice_zh-CN_21956064.mp3', '他被控欺诈破产并被通缉。'),
#  ('common_voice_zh-CN_22003103.mp3', '体育场不时举行联合式橄榄球比赛。'),
#  ('common_voice_zh-CN_22028220.mp3', '磁化学即研究分子原子中特性与磁学相关的化学问题。'),
#  ('common_voice_zh-CN_22029546.mp3', '塘坊清真寺的历史年代为清。'),
#  ('common_voice_zh-CN_22031844.mp3', '楚军用楚国方言说了一阵就退了出去。'),
#  ('common_voice_zh-CN_22032165.mp3', '楚军用楚国方言说了一阵就退了出去。'),
#  ('common_voice_zh-CN_22032174.mp3', '南区是韩国釜山广域市的一个区。'),
#  ('common_voice_zh-CN_22032301.mp3', '南区是韩国釜山广域市的一个区。'),
#  ('common_voice_zh-CN_22032416.mp3', '苹果甜又便宜'),
#  ('common_voice_zh-CN_22033869.mp3', '珍珠宝螺为宝螺科宝螺属下的一个种。'),
#  ('common_voice_zh-CN_22033894.mp3', '珍珠宝螺为宝螺科宝螺属下的一个种。'),
#  ('common_voice_zh-CN_22034650.mp3', '这使他碰遇上了斯莱特。'),
#  ('common_voice_zh-CN_22034655.mp3', '这使他碰遇上了斯莱特。'),
#  ('common_voice_zh-CN_22035577.mp3', '格里利镇区为美国堪萨斯州塞奇威克县辖下的镇区。'),
#  ('common_voice_zh-CN_22035761.mp3', '格里利镇区为美国堪萨斯州塞奇威克县辖下的镇区。'),
#  ('common_voice_zh-CN_22045179.mp3', '梅特乔辛一带原为沙利殊原住民族的地域。'),
#  ('common_voice_zh-CN_22045199.mp3', '他从威斯康辛大学麦迪逊分校获得学士与硕士学位。'),
#  ('common_voice_zh-CN_22045217.mp3', '他从威斯康辛大学麦迪逊分校获得学士与硕士学位。'),
#  ('common_voice_zh-CN_22045226.mp3', '梅特乔辛一带原为沙利殊原住民族的地域。'),
#  ('common_voice_zh-CN_22048492.mp3', '四川荣昌人。'),
#  ('common_voice_zh-CN_22048509.mp3', '四川荣昌人。'),
#  ('common_voice_zh-CN_22049899.mp3', '米尔沃。'),
#  ('common_voice_zh-CN_22050068.mp3', '桥身为钢制。'),
#  ('common_voice_zh-CN_22050256.mp3', '会面导致穆夫提被巴基斯坦一个宗教委员会停职。')]
